# %% [markdown]
# # Dashboard prototype
#
# Repository: `evaluation-trajectories`
#
# Core question: How do we know a frontier model actually improved?

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))
from evaluation_trajectories.evaluation import evaluate_toy_runs
evaluate_toy_runs()

# %% [markdown]
# ## Next steps
#
# Replace the toy trajectory with model outputs, process annotations, stress conditions, and regression comparisons.
